# %% [markdown]
# # Proyecto de ICD - PRO
# ##  Tema: Analisis de la economia cubana
# ### Subtema: Comparacion del panorama economica en el dia a dia de la seociedad cubana y en los sitios web
# ##### ¿Qué pasa cuando un mismo producto existe en dos realidades económicas paralelas? En la Cuba contemporánea, los productos básicos circulan a través de dos circuitos comerciales muy diferentes. Por un lado, están las plataformas digitales que operan en dólares estadounidenses, ofrecen una amplia variedad de productos y realizan entregas a domicilio. Por otro lado, las micro, pequeñas y medianas empresas (mipymes) en la calle venden en pesos cubanos, con inventarios cambiantes y condiciones de exhibición limitadas. Esta investigación nace de una pregunta central: ¿Cómo se manifiesta esta dualidad en términos de precios, disponibilidad y acceso? Para responder a esta pregunta, analizamos 31 establecimientos informales en los municipios de Centro Habana y Plaza (Vedado), y los contrastamos con tres tiendas en línea (CubaMax, Xatapulk, Supermarket23), utilizando la tasa de cambio informal para hacer la comparación. El objetivo va más allá de una simple comparación numérica; buscamos entender qué significa esta segmentación para el acceso a bienes esenciales en una economía fragmentada.

# %% [markdown]
# ##### Para establecer una comparación significativa entre precios expresados en monedas diferentes, es necesario emplear la tasa de cambio informal como factor de conversión. Los datos recopilados entre las fechas de noviembre y diciembre de este año muestran un comportamiento descontrolado, con valores que oscilan entre 410 y 490 pesos cubanos por dólar estadounidense (CUP/USD). La tasa de cambio  que nos enseña "El toque" es la cual nos demuestra como se comporta el dolar informalmente en nuestro país. La utilización de la tasa de cambio convierte los precios en USD de las tiendas online, en la moneda de nuestro pais y a la cual poseen la gran mayoria, el CUP , haciendo posible evaluar la magnitud real de las diferencias.
# ##### Este Grafico demuestra el comportamiento del dolar desde el 20 de Octubre hasta el 17 de diciembre.

# %%
from Elcodigo import * 
tasa_de_cambio_big()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[15], line 2
#       1 from los_malandros import *
# ----> 2 tasa_de_cambio_big()
#
# NameError: name 'tasa_de_cambio_big' is not defined

# %% [markdown]
# ##### Para una mejor visión de su comportamiento errático.

# %%
from Elcodigo import * 
tasa_de_cambio()

# %% [markdown]
# ##### Una vez realizada la conversión monetaria, el análisis revela diferencias sistemáticas en los niveles de precios según el tipo de producto y el canal de distribución. Para los productos básicos de producción nacional o de importación masiva, como el arroz común, el azúcar blanca o el espagueti simple, las diferencias de precio entre el canal callejero y el digital son moderadas, generalmente en un rango del 15% al 30%. Por ejemplo, el arroz presenta un precio promedio aproximado de 680 CUP en las mipymes, mientras que su equivalente convertido desde las tiendas online ronda los 900 CUP. Sin embargo, la brecha se amplía de manera considerable para productos importados considerados premium o especializados. Esta diferencia de precios puede tener diferentes razones sugiere condicionadas por los costos de importación, y el supuesto nivel adquisitivo del comprador. A las compras en linea tambien se le daben agregar los hechos de que a pesar de la gran variedad de productos y tener un precio mas elevado , tambien esta el costo del envio los cuales dependen de la politicas de cada una de estas empresas

# %%
from Elcodigo import *
comparame_esta()
# Out:
# c:\Users\Brayan\anaconda3\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   fig.canvas.print_figure(bytes_io, **kw)

# %% [markdown]
# ##### ¿Qué significa "disponibilidad" en un mercado caracterizado por la intermitencia? Nuestro análisis sobre la presencia de productos en las mipymes muestra una geografía comercial fragmentada. Mientras las tiendas en línea ofrecen catálogos digitales completos y aparentemente ilimitados, las mipymes tienen inventarios físicos limitados que dependen de la disponibilidad. Esta distribución desigual no es solo un dato logístico; transforma el acto de compra en un proceso de búsqueda. El promedio en Cuba depende del tipo de producto , no del producto en si ,ya que para buscar un producto en especifico habria que dedicar un indeterminado tiempo en encontrarlo. La disponibilidad constante y predecible se convierte en un rasgo exclusivo del canal digital, pero con una barrera monetaria que muchos no pueden superar.

# %%
from Elcodigo import *
heatmap()

# %% [markdown]
# ##### ¿Qué marcas son las más comunes en las mipymes y qué indican sobre las dinámicas de abastecimiento? Bueno , la grafica demuestra cuales son las marcas mas comuns de ver en cualquier establecimiento. Su predominio no se debe necesariamente a una preferencia del consumidor, sino a patrones de distribución y rotación garantizada. Estas marcas representan lo que el mercado puede sostener de manera más o menos estable: productos de bajo costo unitario y demanda inelástica, lo que permite la supervivencia del negocio. Es notable la casi total ausencia de marcas internacionales premium, que solo se encuentran en el espacio digital. Esta división de marcas muestra que no se trata simplemente de los mismos productos a diferentes precios, sino de ofertas significativamente distintas. El mercado callejero ofrece una versión básica de la canasta de consumo, mientras que el digital ofrece marcas que sugieren diferenciación, calidad y estatus. La marca se convierte en un indicador social que no solo refleja la capacidad de pago, sino también el acceso a redes de distribución globalizadas.

# %%
from Elcodigo import *
frecu_brand()

# %% [markdown]
# ##### Cómo se materializa la dualidad comercial en un establecimiento específico? Un análisis detallado de cualquier mipyme revela una oferta concentrada en productos básicos con precios ajustados al poder adquisitivo en moneda nacional, siguiendo una lógica de rotación rápida y demanda constante.
#
# ##### Esta oferta limitada crea una barrera estructural: el consumidor que busca mayor variedad o productos especializados encuentra el canal informal insuficiente. Su única alternativa es saltar al mercado digital, enfrentando precios elevados. Esta disyuntiva no es de preferencia, sino de acceso determinado por restricciones económicas, ejemplificando cómo la dualidad de mercados configura experiencias de consumo diferenciadas según la capacidad de pago en una u otra moneda.

# %%
from Elcodigo import *
interactua_capo()
# Out:
# ············································································································································
# PRODUCTOS POR MIPYME
# ······································································
#
# MIPYMES DISPONIBLES
# 1. Mipyme San Rafael y Marquez Gonzales
# 2. Santy's
# 3. Mipyme Belascoin/ San Rafael y San Miguel
# 4. Mipyme Belascoin /Neptuno y San Miguel
# 5. El Encanto
# 6. Mipyme/Neptuno // Concordia
# 7. Mipyme Belascoin/ Virtudes y Animas
# 8. Mipyme Belascoin/Animas y Lagunas
# 9. Mipyme San Lazaro/ San Francisco y Espada
# 10. Mipyme San Lazaro / Espada y San Francisco
# 11. Mipyme San Lazaro/ Espada y Hospital
# 12. Mipyme San Lazaro / Espada y Hospital
# 13. Mipyme San Lazaro/ Hospital y Aramburu
# 14. La farola
# 15. Mipyme Hospital/ Neptuno y Concordia
# 16. Mipyme Infanta / Neptuno y San Miguel
# 17. Mipyme Infanta / Neptuno y San Miguel
# 18. Stella Artois
# 19. Mipyme Infanta /San Rafael y San Martin
# ...

# %% [markdown]
# #### Los datos analizados no solo muestran diferencias de precio, sino que revelan dos sistemas económicos paralelos, cada uno con sus propias reglas y accesos. El mercado digital ofrece variedad y previsibilidad, pero plantea una barrera monetaria que los que dependen de ingresos en moneda nacional no pueden superar. El mercado informal brinda accesibilidad en precios para productos básicos, aunque a costa de incertidumbre y una oferta limitada. Esta dualidad comercial reproduce y agrava las desigualdades existentes. Segmenta a los consumidores según su conexión con flujos de divisas, crea experiencias de consumo muy distintas y determina el acceso a nutrientes y bienestar según la posición económica.
#
#  #### La pregunta que se plantea no es técnica, sino ética y política: ¿Qué tipo de sociedad se forma cuando el acceso a bienes básicos de calidad depende del circuito comercial al que se pertenece? La respuesta va más allá de este estudio, pero sus hallazgos son una base empírica importante para ese debate necesario. La dualidad no es solo un fenómeno de precios; es un mecanismo de estratificación social que opera a diario en las calles y pantallas de La Habana.
