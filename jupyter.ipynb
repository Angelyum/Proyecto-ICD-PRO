# %% [markdown]
# # Proyecto de ICD - PRO
# ##  Tema: Analisis de la economía cubana
# ### Subtema: Comparacion del panorama economica en el dia a dia de la seociedad cubana y en los sitios web
# ##### En la Cuba actual, los productos básicos se existen a través de dos canales comerciales diferentes, que produce un fenómeno conocido como economía dual. Existen plataformas digitales que operan en dólares, ofrecen una amplia variedad y realizan entregas a domicilio, mientras que las pequeñas empresas y vendedores informales en la calle comercian principalmente en pesos cubanos, con inventarios más limitados. Este proyecto que analizó 31 establecimientos formales y tres tiendas en línea, utilizando la tasa de cambio del mercado informal para las comparaciones, tiene como objetivo principal analizar cómo esta segmentación afecta la disponibilidad y el acceso a bienes esenciales para la población.

# %% [markdown]
# ##### Para establecer una comparación significativa entre precios expresados en monedas diferentes, es necesario emplear la tasa de cambio informal como factor de conversión, la cual es la mas usada en la sociedad al contrario de la oficial , que con el paso del tiempo a perdido validez en el mercado , aunque recientemente la tasa oficial cambio el valor del USD a 410.
# ##### La siguiente grafica demuestra el comportamiento de los precios en los ultimos meses del 2025 y a principios del 2016

# %%
from Elcodigo import * 
tasa_de_cambio_big()

# %% [markdown]
# ##### Para una mejor visión de su comportamiento.

# %%
from Elcodigo import * 
tasa_de_cambio()

# %% [markdown]
# ##### Una vez realizada la conversión monetaria, el análisis revela diferencias sistemáticas en los niveles de precios según el tipo de producto y el canal de distribución. La grafica siguiente muestra el promedio de los precios de los productos en los sitios web y los precios de las mipymes lo cuales son las mas accequibles a la población.

# %%
from Elcodigo import *
comparame_esta()

# %% [markdown]
# ##### Entonces la diferencia de precios entre productos , es claramente visible, en base a la última actualización del cambio de la moneda en el toque.  Ademas el costo siempre va a ser mayor del cambio visto ya que los costos de envio por cada sitio web son diferentes
# - *Katapulk* : + $18 USD + manejo
# - *Supermarket* : $7 USD/lb + posibles aranceles
# - *Cubamax* : $2.99 USD/lb Aéreo o $35 USD (caja)
# ##### Pero un punto a favor de los sitios web es la disponibilidad de los productos, en cambio las mipymes tienen que abastecerse periodicamente de los poductos de la cual cada una de ella crea que le traiga mayo beneficio economico a corto plazo.
#
# ##### La siguiente gráfica muestra la disponibilidad de los productos en cada uno de ellas.

# %%
from Elcodigo import *
heatmap()

# %% [markdown]
# ##### ¿Qué marcas son las más comunes en las mipymes y qué indican sobre las dinámicas de abastecimiento? Bueno , la grafica demuestra cuales son las marcas mas comunes de ver en cualquier establecimiento. Su predominio no se debe necesariamente a una preferencia del consumidor, sino a patrones de distribución y rotación garantizada.

# %%
from Elcodigo import *
frecu_brand()

# %% [markdown]
# ##### Cómo se materializa la dualidad comercial en un establecimiento específico? Un análisis detallado de cualquier mipyme revela una oferta concentrada en productos básicos con precios ajustados al poder adquisitivo en moneda nacional, siguiendo una lógica de rotación rápida y demanda constante.
#
# ##### Esta oferta limitada crea una barrera estructural: el consumidor que busca mayor variedad o productos especializados encuentra el canal informal insuficiente. Su única alternativa es saltar al mercado digital, enfrentando precios elevados.
# ##### La siguiente grafica muestra los precios de los productos disponibleds en cada mipyme.

# %%
from Elcodigo import *
interactua_capo()

# %% [markdown]
# #### Los datos analizados no solo muestran diferencias de precio, sino que revelan dos sistemas económicos paralelos, cada uno con sus propias reglas y accesos. El mercado digital ofrece variedad y previsibilidad, pero plantea una barrera monetaria que los que dependen de ingresos en moneda nacional no pueden superar. El mercado informal brinda accesibilidad en precios para productos básicos, aunque a costa de incertidumbre y una oferta limitada.
