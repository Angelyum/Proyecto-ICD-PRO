# %% [markdown]
# # Proyecto de ICD - PRO
# ##  Tema: Análisis de la economía cubana
# ### Subtema: Comparación del panorama económico en el día a día de la sociedad cubana y en los sitios web
# ##### En la Cuba actual, los productos básicos existen a través de dos canales comerciales diferentes, que produce un fenómeno conocido como economía dual. Existen plataformas digitales que operan en dólares, ofrecen una amplia variedad y realizan entregas a domicilio, mientras que las pequeñas empresas y vendedores informales en la calle comercian principalmente en pesos cubanos, con inventarios más limitados. Este proyecto analizó 32 establecimientos formales y tres tiendas en línea, utilizando la tasa de cambio del mercado informal para las comparaciones, tiene como objetivo principal analizar cómo esta segmentación afecta la disponibilidad y la dificultad de acceso a bienes esenciales para la población.

# %% [markdown]
# ##### Para establecer una comparación significativa entre precios expresados en monedas diferentes, es necesario emplear la tasa de cambio informal como factor de conversión, la cual es la más usada en la sociedad, aunque recientemente la tasa oficial cambio el valor del USD a 410.
# ##### La siguiente gráfica demuestra el comportamiento de los precios en los últimos meses del 2025 y a principios del 2026

# %%
from Elcodigo import * 
tasa_de_cambio_big()

# %% [markdown]
# ##### Para una mejor visión de su comportamiento.

# %%
from Elcodigo import * 
tasa_de_cambio()

# %% [markdown]
# ##### Una vez realizada la conversión monetaria, el análisis revela diferencias sistemáticas en los niveles de precios según el tipo de producto y el canal de distribución. La gráfica siguiente muestra el promedio de los precios de los productos en los sitios web y los precios de las mipymes los cuáles son las más accequibles a la población.

# %%
from Elcodigo import *
comparar_mxw()

# %% [markdown]
# ##### Entonces la diferencia de precios entre productos , es claramente visible, en base a la última actualización del cambio de la moneda en el toque.  Además el costo siempre va a ser mayor del cambio visto, ya que los costos de envío por cada sitio web son diferentes
#
# - *Katapulk* : + $18 USD + manejo
# - *Supermarket* : $7 USD/lb + posibles aranceles
# - *Cubamax* : $2.99 USD/lb Aéreo o $35 USD (caja)
#
# ##### Pero un punto a favor de los sitios web es la disponibilidad de los productos, en cambio las mipymes tienen que abastecerse periódicamente de los productos de la cual cada una de ellas crea que le traiga mayor beneficio económico a corto plazo.
#
# ##### La siguiente gráfica muestra la disponibilidad de los productos en cada uno de ellas.

# %%
from Elcodigo import *
heatmap()

# %% [markdown]
# ##### Esta gráfica nos deja claro que la disponibilidad de productos en la mipymes de la calle no es constante , por lo que para poder encontrar un producto en especifico, se tendría que hacer una exploración, al contrario de la disponibilidad comoda que te ofrecen los sitios web.
# ##### ¿Cual es el porcentaje de marcas que existen en un canal con respecto al otro? El siguiente gráfico da un porcentaje exacto de cuantas marcas se pueden encontrar exclusivamente en cada canal.

# %%
from Elcodigo import *
dispo_marcas()
# Out:
#  MARCAS ENCONTRADAS:
# Solo en Mipymes: 53
# Solo en Webs: 120
# En ambos: 39

# %% [markdown]
#  ##### ¿y especificamente cual sería la diferencia de precio de producto de cada mipyme explorada vs el promedio de los precios que ofrecen los sitios web? La siguiente gráfica nos muestra los precios de los productos disponibleds en cada mipyme que se escoja comparados con el promedio de los sitios web.

# %%
from Elcodigo import *
Mipyme_productos()
# Out:
# ······································································
# PRODUCTOS POR MIPYME
# ······································································
#
# MIPYMES
# 1. Mipyme San Rafael y Marquez Gonzales
# 2. Santy's
# 3. Mipyme Belascoin/ San Rafael y San Miguel
# 4. Mipyme Belascoin /Neptuno y San Miguel
# 5. El Encanto
# 6. Mipyme/Neptuno // Concordia
# 7. Mipyme Belascoin/ Virtudes y Animas
# 8. Mipyme Belascoin/Animas y Lagunas
# 9. Mipyme San Lazaro/ San Francisco y Espada
# 10. Mipyme San Lazaro / Espada y San Francisco
# 11. Mipyme San Lazaro/ Espada y Hospital
# 12. Mipyme San Lazaro / Espada y Hospital
# 13. Mipyme San Lazaro/ Hospital y Aramburu
# 14. La farola
# 15. Mipyme Hospital/ Neptuno y Concordia
# 16. Mipyme Infanta / Neptuno y San Miguel
# 17. Mipyme Infanta / Neptuno y San Miguel
# 18. Stella Artois
# 19. Mipyme Infanta /San Rafael y San Martin
# 20. Mipyme Infanta / San Martin y Calle Valle
# 21. Mipyme Infanta/ Calle Valle y Zanja
# ...

# %% [markdown]
# #### Los datos analizados no solo muestran diferencias de precio, sino que revelan dos sistemas económicos paralelos, cada uno con sus propias reglas y accesos. El mercado digital ofrece variedad y previsibilidad, pero plantea una barrera monetaria que los que dependen de ingresos en moneda nacional no pueden superar. El mercado informal brinda accesibilidad en precios para productos básicos, aunque a costa de incertidumbre y una oferta limitada.
